# %% [markdown]
# <a href="https://colab.research.google.com/github/cdube89128/DATA_620/blob/main/DATA_620_HW_Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as net
import matplotlib.pyplot as plt

# Creating the Krackhardt kite social network
g = net.krackhardt_kite_graph()

# Print a few numbers about my arbitrary graph
print("Number of nodes:", g.number_of_nodes())
print("Number of edges:", g.number_of_edges())

# Draw and display my graph
net.draw(g, with_labels=True)
plt.show()
# Out:
# Number of nodes: 10
# Number of edges: 18
